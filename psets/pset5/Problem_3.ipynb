# %%
include("eig.jl")
# Out:
# plot_eigs (generic function with 2 methods)

# %%
immutable V1
end
call(::V1, x) = abs(x)
immutable V2
end
call(::V2, x) = @evalpoly(x, 13 / 10, 1 / 8, -1 / 18, 0, 12 / 10^4)
immutable V3
end
call(::V3, x) = 8 * abs(abs(abs(x) - 1) - 1)
# Out:
# call (generic function with 1238 methods)

# %%
xs = linspace(-12, 12, 1921)
# Out:
# 1921-element LinSpace{Float64}:
#  -12.0,-11.9875,-11.975,-11.9625,-11.95,…,11.95,11.9625,11.975,11.9875,12.0

# %%
Ds1, Vecs1 = eigs_ode(V1(), xs)
plot_eigs(V1(), xs, Ds1, Vecs1)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fc2568c46a0>)
# PyObject <matplotlib.legend.Legend object at 0x7fc256829160>

# %%
Ds2, Vecs2 = eigs_ode(V2(), xs)
plot_eigs(V2(), xs, Ds2, Vecs2)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fc256924160>)
# PyObject <matplotlib.legend.Legend object at 0x7fc2567dc240>

# %%
Ds3, Vecs3 = eigs_ode(V3(), xs)
plot_eigs(V3(), xs, Ds3, Vecs3)
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7fc25689e710>)
# PyObject <matplotlib.legend.Legend object at 0x7fc256b9ea90>
